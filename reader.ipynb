# %% [markdown]
# ### Test 1 page

# %%
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
import io

# Path to your PDF file
pdf_path = 'mathsmaster.pdf'

# Open the PDF file
pdf_document = fitz.open(pdf_path)

# Define your list of page ranges here
# For example: [(1, 5), (10, 12)] would process pages 1 through 5 and 10 through 12
page_ranges = [(5, 7), (10, 12)]

# Loop through each range in the list
for start_page, end_page in page_ranges:
    # Loop through each page in the current range
    for page_number in range(start_page, end_page + 1):
        # Check if the page number is valid
        if page_number < len(pdf_document):
            # Get the specified page
            page = pdf_document[page_number]

            # Extract image from the page
            image_list = page.get_images(full=True)
            if image_list:
                base_image = image_list[0]  # Get the first image (as an example)
                xref = base_image[0]
                base_image = pdf_document.extract_image(xref)
                image_bytes = base_image["image"]

                # Load it to PIL
                image = Image.open(io.BytesIO(image_bytes))

                # Use pytesseract to do OCR on the image
                text = pytesseract.image_to_string(image)

                # Print the text
                print(text)
            else:
                print("No image found on page", page_number)
        else:
            print("Page number out of range")

# Close the PDF after processing
pdf_document.close()
# Out:
# 2 CHAPTER 01 - TIME AND WORK [ @ sit Gaa |
#
# Assistant Primary Teacher 2022
#
# Q.1 Anil alone can complete a work in 28 days and
# Karan alone can complete the same work in half of
# the time taken by Anil. In how many days will both
# together complete 3/7 part of the total work?
#
# site soc up ord of 28 feat Fo a Gea s aT
# Oe see Set ord Ht sitet gna fee me WaT + sey
# SHG A QT HR Gea G1 Sh Pretepe He He HT 3/7 UPT
#
# fear feat a ar ete
# A. 5 days B. 8 days
# C.7 days D. 4 days
#
# {DSSSB Assistant Primary Teacher (NDMC) 23.03.2022 Shift-2}
#
# Q.6 Raman and Kamal do (4/9)"" part of a work and
# the rest of the work is completed by Rohan. If Raman,
# Kamal and Rohan together take the same work for
# Rs. 18000, then what is the share of Rohan?
#
# UV aU HUG Us Hrs HT (4/9)ai HPT Hed S UT NI}
# USA EN RI fa Ga Sl Ale LAA, HAS Ae VST TY
# free set ore GT 18000 Sua A ca & at aes wT SRT
#
# ch,
#
# we?
# A. Rs. 12000 B. Rs. 10000
# C. Rs. 14000 D. Rs. 8000
#
# {DSSSB Assistant Primary Teacher (NDMC) 24.03.2022 Shift-3}
#
# Q.2 A and B can complete a work in 5 days and 20
# days respectively. They work on alternate days one
# at a time and A works on the first day. In how many
# days the whole work will be completed?
#
# A Tea B Ub Ors GT PAR: 5 fer Tea 20 fea A URI HX
# wed 1d aRtant S wp-us fea orf wed & au Ved
# fea ord Gea G1 Gael ore feos fea A aT sl oT?
# A. 12 days B. 8 days
#
# C. 7 days D. 10 days
# {DSSSB Assistant Primary Teacher (NDMC) 23.03.2022 Shift-3}
#
# Q.3 J alone can complete a work in 40 days and K
# alone can complete the same work in 60 days. They
# began the work together, but K left the work 5 days
# before the completion of work. In how many days,
# will the work be completed?
#
# J Heel Up Hrs HI 40 fet A OR HR eva S Ta K Steret
# Sei ord Ht 60 fea A ORI HY Gea Sl Te Te rH
# ord Sea HRY fea, Weg K HTS ORT Sr G 5 fet ud ord
# BSH Te TA! Hrs feos fest A ETI gan SM?
#
# A. 20 days B. 24 days
#
# C. 27 days D. 26 days
# {DSSSB Assistant Primary Teacher (NDMC) 24.03.2022 Shift-1}
#
# Q.7 Pand Q together can complete a work in 10 days.
# Q and R together can complete the same work in 15
# days. If P, Q and R all work together, then the same
# work gets completed in 7.5 days. How many days
# will P and R together take to complete the same
# work?
# P Teal Q Paar Us ares aI 10 fer A URI He Gad 1
# Ta R frerax ell ore GT 15 fer A RI HX Ue EI Ale
# P,Q da R dh free GTA Hed &, ct gel ores 7.5 fer A
# Wee oar a Paar R Haar sah OM HI QW oe & few
# foc fer ci?
#
# A. 15 days B. 5 days
#
# C. 7 days D. 10 days
# {DSSSB Assistant Primary Teacher (NDMC) 25.03.2022 Shift-2}
#
# Q.4 D, E and F hired a car for Rs. 7220. D used it for
# 7 hours, E used it for 5 hours and F used it for 8
# hours. What will be the E’s share in rent?
#
# D, Eda F Um HR Hl 7220 Sud A feed we cd SI DA
# SaGT VSN 7 He fear, EA TAHT VSNL 5 ae fear aa A
# Seo Var 8 de feral fered F e chr fee eT VET?
#
# A. Rs. 2527 B. Rs. 3632
#
# C. Rs. 1805 D. Rs. 2888
# {DSSSB Assistant Primary Teacher (NDMC) 24.03.2022 Shift-1}
#
# Q.5 Some boys can complete a work in 46 days. If
# there were 26 boys more, then the work could be
# finished in 26 days less. What was the number of
# boys in the beginning?
#
# Ho Ish Us ot w 46 fea A OI a Bea ZI Ae 26
# ash ok aa, Ht ors 26 fea wa A ae a wea a
#
# YS A ASHI Ht He KA et
# A. 20 B.17
# c.18 D.10
#
# {DSSSB Assistant Primary Teacher (NDMC) 24.03.2022 Shift-2}
#
# Q.8 X and Y can finish a piece of work in 32 days and
# AO days respectively. X started the work and worked
# at it for 12 days. He was then joined by Y. Find the
# total number of days to finish the work.
#
# X SRY UH Gre ol HAN: 32 fet six 40 feat A war
# ax Ud C1 X A OH YS fear sie Sa UR 12 fer aw
# wre fear Sa Te Y SHS UY Fst! HF PAA SA
# & few pa fel St Sen ad He
#
# A. 22 days B. 24.12 days
#
# C. 25 days D. 23.11 days
# {DSSSB Assistant Primary Teacher (NDMC) 25.03.2022 Shift-3}
#
# Q.9 A and B can do a piece of work in 36 days, B and
# Cin 45 days, and C and A in 60 days. How much time
# will B alone take to finish the job?
#
# ABR B Ue ord OT 36 feat A, B Sik C45 fea A sic
# SARA 60 feat A OX apd EB sa Sa OT HI IGS
# F fear aaa oT?
#
# A. 130 days B. 140 days
#
# C. 120 days D. 60 days
# {DSSSB Assistant Primary Teacher (NDMC) 26.03.2022 Shift-2}
#
# Q.10 Rishab can complete 4/5 part of a work in 16
# days. Rani is 2 times as efficient as Rishab. In how
# many days will Rani alone complete the same work?
# Reay feet pred & 4/5 unt HT 16 feat A RI ae GHA eI
# wa, Roy B 2 Tar orig 81 Wt sie Get ors w
#
# eds fer A ART pet?
# A. 12 days B. 40 days
# C. 11 days D. 10 days
#
# {DSSSB Assistant Primary Teacher (DOE) 07.03.2022 Shift-1}
#
# «< DSSSB CHAPTERWISE MATHS >> {PART-A} Includes All Online Teaching Exam PYQs 2021/22 [RSK>>Raj+Sandeep kharb<]
#
# RAJ (@MasterTalk2050) , MCD PRT Govt Teacher
#
# Q.11 Deepak alone can do a work in 30 hours.
# Deepak and Rahul together can do the same work in
# 20 hours. Rahul and Varun together can do the same
# work in 15 hours. In how many hours can Varun
# alone do the same work?
#
# due strc up ore a 30 de A aH Goa V1 atow aT
# ed Rrearx Set orf a 20 we A HX Gard SI Vga Ta
# ea ferme oe ord Hl 15 We He aod Sl TEA siehet
# Tell ors wt far ee F pe Tey 8?
#
# A. 17 hours B. 22 hours
#
# C. 20 hours D. 25 hours
# {DSSSB Assistant Primary Teacher (DOE) 07.03.2022 Shift-3)
#
# CHAPTER 01 - TIME AND WORK [ @ sit Gaq |
#
# Q.16 Raju completed the science project in 20 days.
# How many days will Guru take to complete the same
# work if he is 25% more efficient than Raju?
#
# Ua A faa UAT HI 20 feat A ur fear AS GS Set
# ord ol RI Ge F feos fet wa ae ae Ue B 25%
#
# oifties Pare 8?
# A. 10 days B. 16 days
# C. 12 days D. 14 days
#
# {DSSSB Assistant Primary Teacher (DOE) 27.03.2022 Shift-2}
#
# Q.12 A work was finished by A, B and C together. A
# and B together finished 30 percent part of the work
# and B and C together finished 80 percent part of the
# work. Who among the three is most efficient?
#
# Ub ore A, BAU C aT fra URI fora TAT! A ae BA
# freer ore oT 30 weed HPT Ug fear aan B aT C A
#
# Q.17 A and B together can do a piece of work in 40
# days. A having worked for 24 days, B finishes the
# remaining work alone in 54 days. In how many days
# shall B finish the whole work alone?
#
# ASR B rca Us ore oT 40 feat HR Ted ELA, 24
# feat ae ort oe & ae, B IN or HI sibel 54 feat A
# RIGA C1 B sieha WY HH ol fos feat A I HET?
# A. 65 days B. 55 days
#
# C. 75 days D. 45 days
# {DSSSB Assistant Primary Teacher (DOE) 27.03.2022 Shift-3}
#
# frerax ore oT 80 Weed eT ORT fear! AAT AS waa
# afte prigarct Hr @?
# A.B B. All are equal
#
# C.A D.C
# {DSSSB Assistant Primary Teacher (DOE) 16.03.2022 Shift-2}
#
# Q.13 18 boys and 24 men can complete a work in 24
# days. Each boy takes thrice the time taken by a man
# to complete the work. In how many days will 24 men
# complete the same work?
#
# 18 Use Tal 24 Gey Up ore HI 24 ea A UI ae a
#
# Q.18 X number of workers are hired to do a job in 10
# days. But since 5 men dropped out every day, the job
# got completed at the end of the 12th day. How many
# men were there at the beginning?
#
# lot donor & faux stat aoa EQ
# Gl tier de ex fea 5 sna wis Ua 8, safer 120 fea S)
# & ofa A GTA URI Bam Year F feast saa A?
#
# A. 165 B. 120
#
# C.105 D.110
# {DSSSB Assistant Primary Teacher (DOE) 29.03.2022 Shift-1}
#
# PRT Govt Teacher
#
# fi uae ass a orf WI oe A ww GEV Err fae aw
# BAT OT ata TAT SAT ATA S| 24 Ge Set re a feat
#
# fea A pe?
# A. 15 days B. 30 days
# C. 60 days D. 45 days
#
# {DSSSB Assistant Primary Teacher (DOE) 16.03.2022 Shift-3}
#
# Q.14 Working 6 hours per day, R1 can complete a
# work in 18 days. Working 15 hours per day, R2 can
# complete the same work in 12 days. Working 9 hours
# per day, in how many days both R1 and R2 together
# can complete the same work?
#
# foie 6 de orf axe, RI UH or al 18 fea A I HE
# Wha S| Wider 15 de ord Heh, R2 Tet ore G1 12 fe
# AQIS THA S| idles 9 de Gl Hed, R1 TU R2 St
# friar Sel Hrd Hl foros fer A ORI HX apd ?
#
# A.7.5 days B. 9 days
#
# C. 8 days D. 10.5 days
# {DSSSB Assistant Primary Teacher (DOE) 20.03.2022 Shift-1}
#
# Q.19 A, B and C can complete a piece of work in 32,
# 16 and 40 days respectively. Working together, they
# will complete the same work in days.
#
# A, BUR C Up He HI Ha: 32, 16 sik 40 feat a MT HR
# Ud El Us TY He Hrd FY Feil Hel wT fet
#
# ARQIaw|
# A. 160/13 B. 160/19
# C. 190/13 D. 190/11
#
# {DSSSB Assistant Primary Teacher (DOE) 29.03.2022 Shift-2}
#
# Q.15 30 men or 50 women can do a work in 72 days.
# How long will 15 men and 25 women take to do it?
# 30 Fey a 50 Heart fret ard ot 72 feat a Ee ed eI
# 15 Geet sik 25 aera a1 sa oer A faa Baa TI
# A. 60 days B. 84 days
#
# C. 48 days D. 72 days
# {DSSSB Assistant Primary Teacher (DOE) 27.03.2022 Shift-1}
#
# Q.20 Gargi is thrice as good a worker as Julliet and
# takes 6 days less to do a piece of work than Julliet.
# In how many days can Julliet complete the same
# work?
#
# anit afere @ ger 4 fe Ta srw orioat & sik
# wfc oF gern A te ord oI es A 6 fer HH ae BI
# were Sel pred al foo feat A aR HX Gard 8?
#
# A.9 days B. 6 days
#
# C. 15 days D. 12 days
# {DSSSB Assistant Primary Teacher (DOE) 29.03.2022 Shift-3}
#
# RAJ (@MasterTalk2050) , M
#
# «< DSSSB CHAPTERWISE MATHS >> {PART-A} Includes All Online Teaching Exam PYQs 2021/22 [RSK>>Raj+Sandeep kharb<]
#
# Q.21 Kamal can do a piece of work in 18 days and
# Kamlesh can do the same work in 36 days. They
# started the work and after 6 days Sunil joined them,
# who can complete the same whole work in 6 days.
# What is the total number of days in which they had
# completed the work?
#
# be Up Hrd wl 18 feat A He Gear s sik HAT Tet
# ord o 36 feat A ae Goal 81 SSM Hr YS fat six
# 6 fet & ae Gta Gad Ure Ger, vi Tet Gy Gre HT 6
# feat FQ oe Ged ol pa for feat A eA ord RT
# ferar an?
# A. 16
# c.10
#
# B.6
#
# D.8
# {DSSSB Assistant Primary Teacher (DOE) 30.03.2022 Shift-1}
#
# CHAPTER 01 - TIME AND WORK [ @ sit Gaq |
#
# Q.3 Pis 20 percent more efficient than Q. P alone can
# do a work in 2 days less than Q alone. In how many
# days can they do the work together?
#
# P,Q ¥ 20 aad siftia Hera sl p seen UH Hr ST Q
# & sibel He G 2 fet wy A oY Gea Sl d UH Te HT
#
# wl fies feat a ox ward 8?
# a fF 9
# 60 40
# c= dD
# y 3 9
#
# {DSSSB TGT Computer Science 01.08.2021 Shift-3}
#
# Q.22 Five men can do half of work in 20 days. How
# many men are require to do a piece of work in four
# days?
#
# Ufa Gey aren wre 20 feat a oR aed SUH Hrs HT aR
# fet toe & fee feat gout wt sagan erie
#
# A. 50 B. 100
#
# C.25 D. 20
# {DSSSB Assistant Primary Teacher (DOE) 30.03.2022 Shift-3}
#
# Q.4 P, Q and R alone can do a work in 12, 18 and 24
# days respectively. They worked for 5 days, 4 days
# and 6 days respectively. They received Rs. 32000.
# What is the share of Q?
#
# P, QTR Siebel Uh GH Hl HH: 12, 18 dat 24 fea
# aX Ud Sl de Ha: 5 fea, 4 fer ae 6 fea orf wed
# G1 TS 32000 SIA Fei Q HT SRA RA V?
#
# A. 12000 B. 6000
#
# C. 15000 D. 8000
# {DSSSB TGT Computer Science 07.08.2021 Shift-1}
#
# ANSWER KEY
# [Assistant Primary Teacher (NDMC & DOE) 2022]
# Q.2 Q3  Q4 Q5 Q6
# B D c UA B
# a8 Q9 Q10 Q11 Q12
# D D D Cc D
# Q.15  Q16 Q17 Q18
#
# Q.14
#
# A D B |
# Q.20 Q.21 Q.22—
# A D A
#
# TGT 2021
#
# Q.1 10 men can do a work in 15 days working 4 hours
# a day. If after 5 days, 4 men leave the work, then
# remaining work can be done in how many days?
#
# 10 ster um fea A 4 de or eRe 15 eal Aue oH
# HX Gea S1 Ae 5 feat & ag, 4 sah ord wis 2a Zl
#
# ate pred fara feat F ferar or sara S2*
# A.20 B. 50/3
# C. 53/3 D.18
#
# {DSSSB TGT Computer Science 01.08.2021 Shift-2}
#
# 4 9
# Q. 2A student reads 3 of a book on a day and to
#
# of the rest on the second day. The number of pages
# still unread are 60. How many pages does the book
# contain?
#
# up faerelf un fea un frcra aT 4/9 UgaT e Ta IY wT
# 9/10 Ba fer Use S1 sf at a Ue TA Gat St aT 60
#
# 81 fara A fora oa 82
# A. 1020 B. 920
# c.940 D. 1080
#
# {DSSSB TGT Computer Science 01.08.2021 Shift-3}
#
# Q.5 P and Q alone can do a work in 18 and 45 days
# respectively. They started the work together and P
# left after 3 days of start of work. Q completed the
# remaining work. In how many days was the work
# completed?
#
# P Ta _Q sibel Ue Get Hl PAM: 18 Teal 45 fer A HE
# tod €| Se ae oe YS far ane oA YS OAS
# 3 fea Te Sls H Te TM! QA Ta Ban HF sia Wa
# foro! pre feos fer A aR gan?
# A. 36
#
# C. 37.5
#
# B. 39.5
# D. 34
# {DSSSB TGT Computer Science 07.08.2021 Shift-2}
#
# Q.6 A and B alone can do a work in 12 and 18 days
# respectively. A, B and C together can do the same work
# in 6 days. In how many days can C do the work alone?
# A TUB sebea Ub Hrs Gt PAN: 12 da 18 fet A HK
# Hd sl A Bac Haar sel or oT 6 fer a a ad
# Sl c seber foes fea A red HX Wea S?
# A. 24 B. 30
# Cc. 48 D. 36
#
# {DSSSB TGT Computer Science 07.08.2021 Shift-3}
#
# Q.7 X alone takes 40 percent more time than Y alone
# to complete the work. If together they can complete
# the work in 15 days, then how many days will Y take
# alone to do the work?
#
# ue orf al OT He A x ster, y steve S 40 Ufa
#
# oft ara dat 21 afe ag are Prawe orf wt 15 fea A
# WI aX Tad @, a ord al wef eel a y sie fers fea
# wm
#
# 33 31
# A= B. =
#
# 4 5
#
# 165 180
# Cc. e D. =
#
# 7
# {DSSSB TGT Physical Education Teacher 02.08.2021 Shift-1}
#
# «< DSSSB CHAPTERWISE MATHS >> {PART-A} Includes All Online Teaching Exam PYQs 2021/22 [RSK>>Raj+Sandeep kharb<]
#
# RAJ (@MasterTalk2050) , MCD PRT Govt Teacher
#
# Q.27 A wall is constructed with dimensions 22 m
# long, 9 m high and 72 cm thick. If 20% of the wall is
# filled with mortar and each brick measures
# 22cmx12cmx9cm, then find the number of bricks
# required to construct the wall.
#
# 22 Hex tia, 9 Hex Gehl sik 72 Safer HA staat are
# we dar a1 Prato fen ren 81 ate clare oT 20% Hreke G
# ARTS Sh Wa Se HT ANT 22cemx12cmxI9em B, TH aR
#
# Frater & fere straxae gel Ht Gen aa Hifera*
# 1. 48000 2. 15400
# 3. 28000 4.4700
#
# {DSSSB TGT Maths Female 10.09.2021 Shift-2}
#
# CHAPTER 01 - TIME AND WORK [ @ sit Gaq |
#
# Q.32 If five men and six women or four men and eight
# women can complete a piece of work, then what is
# the ratio of efficiency of one man and one woman?
# Ofe Ula Gey sik Se AfSMTS AIR YS SR sito ASeTe
# foe ord al ORT GX Tend &, Gl UH Goes sik Up Aiea
# al Sete BT SGOT FA 8?
# A.2:1
#
# C.3:2
#
# B.2:3
# D.1:2
# {DSSSB TGT Hindi Female 04.09.2021 Shift-2}
#
# Q.28 Manoj and Nandan working together can do a
# certain amount of job in 45 days and are paid
# Rs.12600 for the whole job. The efficiency ratio of
# Manoj and Nandan is 9:5. Find the daily wages of
# Nandan, if they get paid as per their efficiency.
# Ale SiR Acq Ub Sry GTA Sd gu UH Pa URIS
# 45 feat a ae Ged & sik SS i atewd & fore 12600
# VUE Hl UTA fal Ga Sl AA sie Aaa GT Gala
# HPT 9:5 Sl Aaa St ew Tora wa Hiforw, afe Te
# STS) Geel & sea para Frere
# 1. Rs. 100 2. Rs. 90
# 3.Rs.105 4. Rs. 120
#
# {DSSSB TGT Maths Female 10.09.2021 Shift-3}
#
# Q.33 Sudhakar can finish a piece of work in 15 days
# and Bina can finish the 1/5th of the same work in 6
# days. In how many days together they can finish the
# 3/5th part of the total work?
#
# Garay Up red HH 15 feat A acd Ge Tea S SIR ST
# oat ord oT 1/5 UT 6 feat A Taca HE Gerd Sl a UH
# UY Ha HS HT 3/5 uly feos fea A oR HY Tard 8?
# A.3 days B. 4 days
#
# C. 6 days D. 2 days
# {DSSSB TGT Hindi Female 04.09.2021 Shift-2}
#
# Q.29 A farm house can be built by a number of
# workers in 22 days. While their 3 workers were
# absent, so it took 24 days to complete the work.
# What was the actual number of workers?
# 22 eal A og sfteat gra ue wr se SAT OT Bea
# Sl wale Sas 3 afant sque 8, safe om RI
# Oe F 24 fer ll aftept pt araiaw en aa al
# A.72 B. 36
# C.24 D. 40
#
# {DSSSB TGT Maths Female 11.09.2021 Shift-3}
#
# Q.34 Sanju, Suraj and Sanjay can complete a work in
# 12 days, 16 days and 24 days respectively. In how
# many days will the three of them complete the same
# work together?
#
# GG, RT SR Gor Up Hrs wl HA: 12 (eH, 16 fea si
# 241TH RTO Ged C1 a cit firtepe Sel ores 1 feo
#
# feat Aug pitt?
# A. 16/3 days B. 6 days
# C. 58/9 days D. 8 days
#
# {DSSSB TGT Hindi Female 04.09.2021 Shift-3}
#
# Q.30 The three person A, B and C.can complete the
# work in 40 days. If the ratio of efficiencies of A, Band
# Cis 3:2:5, then find in how many days A and C
# together can complete (2/5)" part of that work.
#
# dis cafed a, BIR C40 feat A ord wl ORI HY Herd BI
# Oe A, B SAR C Ht Gaeta HT saa 3:2:5 B, Tt ad He
#
# Q.35 5 men complete the same work in 8 days. 4 women
# complete the same work in 12 days. In how many days will
# one man and 2 women complete a work?
#
# 5 seth oe ord ot 8 feat A og ped SI 4 Hisae ett
# ord ot 12 feat A I Hed 1 Us steht six 2 Hise
#
# up ord ot far feat A a pe?
# A. 30 days B. 16 days
# C. 25 days D. 15 days
#
# {DSSSB TGT Hindi Female 04.09.2021 Shift-3}
#
# Q.36 Arun can complete a work in 10 days and Bimla
# can complete the work in 20 days. If they both work
# for 2 days, then how much work is left?
#
# fe a sik c raw sa ore OT (2/5) uTT foes feat F ORT
# aX Hd el
#
# A. 25 days B. 15 days
# C. 20 days D. 16 days
# {DSSSB TGT Maths Female 11.09.2021 Shift-3)
#
# Q.31 Ram and Shyam can do a job in 25 days
# together. If Ram alone takes 30 days to do the job
# then how long does Shyam take?
# TH SAR ROTH Up Ue 25 fea a Uw ord He Ted el aie
# We see Ta orf Gt A F 30 fest Tens, dl Lay H
# fecal aaa eePT?
# A.115 days
#
# C. 125 days
#
# B. 105 days
#
# D. 150 days
# {DSSSB TGT Maths Female 13.09.2021 Shift-1}
#
# SOU Us red Ht 10 feat A IH Tea S sik fae 20
# feat A I aR Tech BI ae d att 2 fea GH aed Ba
#
# feral Gr Ta 8?
# 1.0.5 2.0.7
# 3.0.6 4.0.8
#
# {DSSSB TGT Hindi Female 05.09.2021 Shift-1}
#
# Q.37 Kush & Luv take 10 days to complete the work
# together. If Kush takes 15 days to complete the work
# alone, how long will Luv take to complete the work alone?
# PI si wa Us Gre Hrs HI Ie F 10 fer aa EI Ale
# PI shel HY Hi I HIF 15 fer ca B, i aa sia
# ord oR ee F foc waa a1?
# 1.25 days 2. 20 days
#
# 3.30 days 4. 35 days
# {DSSSB TGT Hindi Female 05.09.2021 Shift-1}
#
# «< DSSSB CHAPTERWISE MATHS >> {PART-A} Includes All Online Teaching Exam PYQs 2021/22 [RSK>>Raj+Sandeep kharb<]
#
# RAJ (@MasterTalk2050) , MCD PRT Govt Teacher
#
# Q.38 A and B together can doa piece of work in 10 days,
# B and C together can do the same work in 25 days and
# C and A together can do the same work in 50 days. In
# how many days they together will complete the same
# work?*
#
# A Six B fica feoett ort oT 10 feat A ped & B sie
# Froaae sel ord wt 25 feta wed S ARC SHR A fea
# Seat ord S50 feta od 1 o cat fax sat ord GT
#
# feos feat a a eae
# 1.25/12 fe 2.25 fea
# 3.25/83 fet 4.12.5 1e4
#
# {DSSSB TGT Hindi Female 05.09.2021 Shift-2}
#
# Q.39 Q's efficiency is 40% of P's. P and Q can complete
# a work in 12 days. In how much time can Q alone do it?*
# Q OI aa P HI 40% 31 PARQ UH Oe G1 12 feat A
# WRI EX Gad 1 Q seer Sa foc Baa A HE Beal 8?
# A.21 fet B. 42 fe
# c.31 fea D. 24 fe
#
# {DSSSB TGT Hindi Male 18.09.2021 Shift-1}
#
# CHAPTER 01 - TIME AND WORK [ @ sit Gaq |
#
# Q.43 Shyam alone can do a work in 40 days working
# 2 hours a day. Ram alone can do the same work in
# 60 days working 2 hours a day. How many hours do
# they need to work together in a day to complete the
# same work in 12 days?
#
# RO stra Ufates 2 te ord we us wf wr 40 fea
# RX VHA Sl UA seve Get ord a vices 2 de orf
# are 60 fer A oY Goal Bl Set ors wT 12 fea AT
# Oe & fae Se oldies ure frre fort de ort eA
#
# wr sqaRTHA 8?
# 1. 5 hours 2. 2.5 hours
# 3. 3 hours 4. 4hours
#
# {DSSSB TGT Social Science Male 06.09.2021 Shift-1}
#
# Q.40 A is 45% more efficient than B, and B takes 9 days
# more than A to complete a piece of work. In how many
# days will A complete the same work?*
#
# ABU 45% sift Hd ¢, HR BUS os SI RI GF
#
# Q.44 K alone can do (3/10) part of a work in 3 hours.
# L alone can do (3/5) part of same work in 6 hours. If
# they work together, then how many hours will they
# take to complete (1/2) part of the same work?
#
# K Hebd Us Gres ST (3/10) UT 3 He A EL GH SL
# eet TH HF ST (3/5) UP 6 Ge H aR Waa S1 ale
# ae ary rarer ord ara 8, dt gat Hef & (1/2) uPTSet
#
# Rae & few ae feos ee a?
# 1. 2.5 hours 2. 3 hours
# 3. 6 hours 4. 5 hours
#
# {DSSSB TGT Social Science Male 06.09.2021 Shift-2}
#
# AG 9 fer sities dat 81 A Set ord aI QT et A feo
#
# fea erm?
# A. 30 fe B. 24 fe
# c. 29 fe D. 20 fe
#
# {DSSSB TGT Hindi Male 18.09.2021 Shift-1}
#
# Q.41 A goldsmith makes a necklace in 15 days. If he
# wants to complete it in 5 days, then by what percent will
# he have to increase its efficiency?*
#
# Us WAR 15 feat A Us SR saa e1 ale ae sa 5 feat A
# WI SEI Teal @, dt Sa saat cara F fers ufaera wt
#
# Ge pet ert?
# A. 100% B: 150%
# C. 200% D. 300%
#
# {DSSSB TGT Hindi Male 18.09.2021 Shift-2}
#
# Q.45 Ashu and Soniya can together do a work in 20
# days. If Ashu works with four times of his efficiency
# and Soniya works with her half efficiency, then the
# work gets completed in 12 days. In how many days
# can Ashu and Soniya respectively do the work alone?
# SY Tal Sitar fra UH Hrs HI 20 ea Ao ed e1
# ate sry sot aR TT emia S ore Hea aa Sia
# oot snet anran S ord ad 8, il ort 12 fea A or et
# We Sl HAN: SY Tal MAA seat ors G1 foc fea A
# TRI Hx Ue 8?
#
# 1. 40 days, 60 days 2. 30 days, 60 days
#
# 3.15 days, 60 days 4. 60 days, 30 days
# {DSSSB TGT Social Science Male 06.09.2021 Shift-3}
#
# Q.42 A can do 10% of the work in 1.8 days. B takes 6
# days more than A to complete the same work. The
# efficiency of C is 20% more than that of A. A starts a
# work and B and C join him on every second and third
# day respectively, then in how many days will 80% of the
# work be completed?*
#
# A10% Te Ht 1.8 feat A HL THA S| BAM GS SRI
#
# Q.46 B and C alone can do a piece of work in 5 days and
# 15 days respectively. They started the work together
# but after some days B left the work and the remaining
# work was completed by C alone in 3 days. After how
# many days did B leave from the start?*
#
# Bau C abe Ue ord I HAT: 5 fer aa 15 fea AT
# ar Ud C1 Te MY A ord sey fear weg Go fea b
# wan Ba ord wis fear aan te wri cA set 3 fea a
#
# PAA D6 fea sills tar 1 C HT arian AS 20% sills
#
# SLA Uh OM YS ST AR WAS AR sik ARR fea
#
# PAN: BAR C Sas Ma Ys & at Hrs GT 80% far
#
# feat A ar em?
#
# A. 9(12/44) days B. 8(35/44) days
#
# C. 7(9/10) days D. 10(12/44) days
# {DSSSB TGT Hindi Male 18.09.2021 Shift-2}
#
# WR ae fear! ORY S fears fea & van BA oe Sst a?
# A. 1.5 days B. 4 days
# C.3 days D. 5 days
#
# {DSSSB TGT Social Science Female 01.10.2021 Shift-1}
#
# «< DSSSB CHAPTERWISE MATHS >> {PART-A} Includes All Online Teaching Exam PYQs 2021/22 [RSK>>Raj+Sandeep kharb<]
#
# RAJ (@MasterTalk2050) , MCD PRT Govt Teacher
#
# Q.47 X alone can do a work in 30 days. Y alone can
# do the same work in 48 days. They work on alternate
# days one at a time starting with X on the first day. In
# how many days the work will be completed?
#
# X Sebel Up Hrs wt 30 fer A HX ear V1 Y star set
#
# CHAPTER 01 - TIME AND WORK [ @ sit Gaq |
#
# Q.53 A and B together can complete a work in 8 days
# while B and C together can complete it in 12 days. A
# worked for 4 days, B worked for 6 days and then C
# finishes the remaining work in 11 days. In what time
# C alone can complete the work?
#
# ord pt 48 fet AX Gea el Ted fer XS SIN Hd BU
#
# ASR BUG Ue 8 fel Forel oT RI GX tend € Tah B
#
# ae SN-aN 8 Us-un fer ord aed SI wre fear fea F
# We el ore?
# A. 147/4 days B. 480/13 days
#
# C. 510/13 days D. 148/5 days
# {DSSSB TGT Social Science Female 01.10.2021 Shift-2}
#
# Q.48 2 men or 3 boys can complete a work in 96
# days. 6 men and 7 boys will complete the same work
# in how many days?
#
# 2 FRI TT 3 ash UH ol @
# Gey aul 7 ash Sat ars w
# A. 27 days B. 18 days
#
# C. 36 days D. 21 days
# {DSSSB TGT Social Science Female 09.10.2021 Shift-1}
#
# 96 fer A ORT eR Uae SI 6
# foc fea A aR eet?
#
# ok cup Uy Hrs Ht 12 feat A RI oY Gawd G1 AA 4
# feat & fare ord fear, BA 6 feat & fore wre fear six c
# as ord of 11 feat A ag Hea V1 seat c feast feat F
#
# Hrd SIRI HX Wha 8?
# 1.27 days 2.18 days
# 3.17 days 4.11 days
#
# {DSSSB TGT Natural Science Male 07.09.2021 Shift-2}
#
# Q.49 30 men can do a work in 16 days while 6 boys can
# do the same work in 120 days. In how many days 12
# boys and 8 men together will complete the same work?
# 30 Feu up ard oF 16 fea A ax wad ¢ Hale 6 ISH
# oat ord G1 120 fea F HR Gera G1 12 TSH AUT 8 SY
#
# are firtar sel ord 1 fcr fea F RI Se?
# A. 30 days B. 45 days
# C. 40 days D. 60 days
#
# {DSSSB TGT Social Science Female 09.10.2021 Shift-2}
#
# Q.54 P, Q, R worked together for 10 days and
# received Rs.24000 as wages and they share the
# wages in the ratio of 5:2:1 respectively. If P alone
# does the work, then in how many days he can
# complete the work?
#
# P,Q, R910 feat & fee Ua ere TA fea site HTT
# By F 24000 Vad wits fu six 4 HAM: 5:2:1 F sara
# F marge aren Hrd eI ale P ser orf Hea z, al ae
#
# ore ol foo feat A oR HX eva 8?
# 1.18 2.15
# 3.16 4.12
#
# {DSSSB TGT Natural Science Male 07.09.2021 Shift-3}
#
# Q.50 There are 150 men in a group. They have food
# for 15 days. After 10 days, 100 more men join the
# group. Remaining food will last for how many days?
# Ub Ug A 150 Yeu Cl Sth UG 15 fer GT horT Sl 10
# fer Uae 100 YSN GAS A fra st ord S1 IT vis
# fear fet ae ae?
#
# A. 3 days B. 2 days
#
# C. 5 days D. 4 days
# {DSSSB TGT Social Science Female 09.10.2021 Shift-3}
#
# Q.51 Mohit and Rohit together can complete a work
# in 15 days. If Mohit is thrice as efficient as Rohit, then
# in how many days can Rohit alone complete the
# same work?
#
# Filed cen tied firaax wep ore oT 15 fea A HR Ged EI
# afe aifed, tifea 8 dia a odpaa ¢, a tea seer
#
# BAM OTe HI fear fea A RI HR Tea 8?
# A. 45 days B. 90 days
# C. 60 days D. 20 days
#
# {DSSSB TGT Social Science Female 10.10.2021 Shift-1}
#
# Q.55 A person takes a contract to construct a road.
# He constructs 20 percent of the road on the first day,
# 30 percent of the remaining road on the second day,
# 50 percent of the remaining road on the third day,
# and the rest 7 km road on the fourth day. What is the
# length of the road?
#
# Us afdd use Fafa ar so da 8! de ed fe 20
# was Use HI afr era 8, Ws Usew aT 30 vlagra
# Ga FoF, MI Ass HT 50 Waara Ha fea sie Ay 7 fort
# UsH Ha fs Gaal 81 UsH SH cars fat 8?
#
# 1.50 km 2.49 km
#
# 3.35 km 4.25km
# {DSSSB TGT Natural Science Male 08.09.2021 Shift-1}
#
# Q.52 Fifty six men can complete a piece of work in
# 24 days. In how many days can 42 men complete the
# same piece of work?
#
# 56 USN 24 fea A Uap HT GI I aX Ged C1 Set GTA
# I 42 US feos feat A ORI HX Gard 8?
#
# 1.18 days 2.98 days
#
# 3. 48 days 4.32 days
# {DSSSB TGT Natural Science Male 07.09.2021 Shift-2}
#
# Q.56 A can do a certain work in 20 days and B can do
# the same work in 24 days. A works alone for 1 day,
# then B works alone for 2 days, then A works alone for
# 3 days, then B works alone for 4 days, and so on. On
# which day will the work be completed?
#
# Awe Pac Hrd OI 20 eat a HX Tears SiR BT HF
# wl 24 tA GR THA SA Heel 1 fer Hrs Hea g, HX
# B sibel 2 fer Gre Grail &, fhe a siebet 3 fer Hrd HAT
# © fee B seh 4 fer ord axa S, si Se Rel ord fa
#
# fea RI er?
# 1. 24" day 2. 23'4 day
# 3. 20" day 4.22" day
#
# {DSSSB TGT Natural Science Male 08.09.2021 Shift-1}
#
# «< DSSSB CHAPTERWISE MATHS >> {PART-A} Includes All Online Teaching Exam PYQs 2021/22 [RSK>>Raj+Sandeep kharb<]
#
# RAJ (@MasterTalk2050) , MCD PRT Govt Teacher

# %%
import pandas as pd
import re

# Sample text from OCR output
ocr_text = """
Q.11 Deepak alone can do a work in 30 hours.
Deepak and Rahul together can do the same work in
20 hours. Rahul and Varun together can do the same
work in 15 hours. In how many hours can Varun
alone do the same work?

due strc up ore a 30 de A aH Goa V1 atow aT
ed Rrearx Set orf a 20 we A HX Gard SI Vga Ta
ea ferme oe ord Hl 15 We He aod Sl TEA siehet
Tell ors wt far ee F pe Tey 8?

A. 17 hours B. 22 hours

C. 20 hours D. 25 hours
{DSSSB Assistant Primary Teacher (DOE) 07.03.2022 Shift-3)

CHAPTER 01 - TIME AND WORK [ @ sit Gaq |

Q.16 Raju completed the science project in 20 days.
How many days will Guru take to complete the same
work if he is 25% more efficient than Raju?

Ua A faa UAT HI 20 feat A ur fear AS GS Set
ord ol RI Ge F feos fet wa ae ae Ue B 25%

oifties Pare 8?
A. 10 days B. 16 days
C. 12 days D. 14 days

{DSSSB Assistant Primary Teacher (DOE) 27.03.2022 Shift-2}

Q.12 A work was finished by A, B and C together. A
and B together finished 30 percent part of the work
and B and C together finished 80 percent part of the
work. Who among the three is most efficient?

Ub ore A, BAU C aT fra URI fora TAT! A ae BA
freer ore oT 30 weed HPT Ug fear aan B aT C A

Q.17 A and B together can do a piece of work in 40
days. A having worked for 24 days, B finishes the
remaining work alone in 54 days. In how many days
shall B finish the whole work alone?

ASR B rca Us ore oT 40 feat HR Ted ELA, 24
feat ae ort oe & ae, B IN or HI sibel 54 feat A
RIGA C1 B sieha WY HH ol fos feat A I HET?
A. 65 days B. 55 days

C. 75 days D. 45 days
{DSSSB Assistant Primary Teacher (DOE) 27.03.2022 Shift-3}

frerax ore oT 80 Weed eT ORT fear! AAT AS waa
afte prigarct Hr @?
A.B B. All are equal

C.A D.C
{DSSSB Assistant Primary Teacher (DOE) 16.03.2022 Shift-2}

Q.13 18 boys and 24 men can complete a work in 24
days. Each boy takes thrice the time taken by a man
to complete the work. In how many days will 24 men
complete the same work?

18 Use Tal 24 Gey Up ore HI 24 ea A UI ae a

Q.18 X number of workers are hired to do a job in 10
days. But since 5 men dropped out every day, the job
got completed at the end of the 12th day. How many
men were there at the beginning?

lot donor & faux stat aoa EQ
Gl tier de ex fea 5 sna wis Ua 8, safer 120 fea S)
& ofa A GTA URI Bam Year F feast saa A?

A. 165 B. 120

C.105 D.110
{DSSSB Assistant Primary Teacher (DOE) 29.03.2022 Shift-1}

PRT Govt Teacher

fi uae ass a orf WI oe A ww GEV Err fae aw
BAT OT ata TAT SAT ATA S| 24 Ge Set re a feat

fea A pe?
A. 15 days B. 30 days
C. 60 days D. 45 days

{DSSSB Assistant Primary Teacher (DOE) 16.03.2022 Shift-3}

Q.14 Working 6 hours per day, R1 can complete a
work in 18 days. Working 15 hours per day, R2 can
complete the same work in 12 days. Working 9 hours
per day, in how many days both R1 and R2 together
can complete the same work?

foie 6 de orf axe, RI UH or al 18 fea A I HE
Wha S| Wider 15 de ord Heh, R2 Tet ore G1 12 fe
AQIS THA S| idles 9 de Gl Hed, R1 TU R2 St
friar Sel Hrd Hl foros fer A ORI HX apd ?

A.7.5 days B. 9 days

C. 8 days D. 10.5 days
{DSSSB Assistant Primary Teacher (DOE) 20.03.2022 Shift-1}

Q.19 A, B and C can complete a piece of work in 32,
16 and 40 days respectively. Working together, they
will complete the same work in days.

A, BUR C Up He HI Ha: 32, 16 sik 40 feat a MT HR
Ud El Us TY He Hrd FY Feil Hel wT fet

ARQIaw|
A. 160/13 B. 160/19
C. 190/13 D. 190/11

{DSSSB Assistant Primary Teacher (DOE) 29.03.2022 Shift-2}

Q.15 30 men or 50 women can do a work in 72 days.
How long will 15 men and 25 women take to do it?
30 Fey a 50 Heart fret ard ot 72 feat a Ee ed eI
15 Geet sik 25 aera a1 sa oer A faa Baa TI
A. 60 days B. 84 days

C. 48 days D. 72 days
{DSSSB Assistant Primary Teacher (DOE) 27.03.2022 Shift-1}

Q.20 Gargi is thrice as good a worker as Julliet and
takes 6 days less to do a piece of work than Julliet.
In how many days can Julliet complete the same
work?

anit afere @ ger 4 fe Ta srw orioat & sik
wfc oF gern A te ord oI es A 6 fer HH ae BI
were Sel pred al foo feat A aR HX Gard 8?

A.9 days B. 6 days

C. 15 days D. 12 days
{DSSSB Assistant Primary Teacher (DOE) 29.03.2022 Shift-3}

RAJ (@MasterTalk2050) , M

«< DSSSB CHAPTERWISE MATHS >> {PART-A} Includes All Online Teaching Exam PYQs 2021/22 [RSK>>Raj+Sandeep kharb<]

"""

# Regex pattern for the topic 
topic_pattern = re.compile(r'CHAPTER \d+ - (.*?) \[', re.DOTALL)

# Regex pattern for questions - modified to capture everything up to the first question mark
question_pattern = re.compile(r'(Q\.\d+.*?\?)', re.DOTALL)

# Regex pattern for dates
date_pattern = re.compile(r'\{DSSSB.*?(\d{2}\.\d{2}\.\d{4}).*?\}', re.DOTALL)

# Find the topic in the text
topic_match = topic_pattern.search(ocr_text)
topic = topic_match.group(1) if topic_match else 'Unknown Topic'

# Find all matches for Questions and Dates in the text
questions = question_pattern.findall(ocr_text)
dates = date_pattern.findall(ocr_text)

# Check if we found the same number of questions and dates
if len(questions) != len(dates):
    print("The number of questions does not match the number of dates found.")

# Combine the questions, dates, and topic into a list of tuples
combined_data = [(question, date, topic) for question, date in zip(questions, dates)]

# Create a pandas DataFrame
df = pd.DataFrame(combined_data, columns=['Question', 'Date', 'Topic'])

# Write the DataFrame to an Excel file
excel_output_path = 'output.xlsx'
df.to_excel(excel_output_path, index=False)

print(f"Data has been written to {excel_output_path}")
# Out:
# Data has been written to output.xlsx

# %% [markdown]
# # OCR + Output

# %%
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
import io
import re
import pandas as pd

# Path to your PDF file
pdf_path = 'mathsmaster.pdf'

# Open the PDF file
pdf_document = fitz.open(pdf_path)

# Define your list of page ranges here
page_ranges = [(5, 301)]

# Regex patterns
topic_pattern = re.compile(r'CHAPTER \d+ - (.*?) \[', re.DOTALL)
question_pattern = re.compile(r'(Q\.\d+.*?\?)', re.DOTALL)
date_pattern = re.compile(r'\{DSSSB.*?(\d{2}\.\d{2}\.\d{4}).*?\}', re.DOTALL)

# Placeholder for all extracted data
extracted_data = []

# Process each page range
for start_page, end_page in page_ranges:
    # Current topic placeholder
    current_topic = "Unknown Topic"
    
    # Process each page in the range
    for page_number in range(start_page, end_page + 1):
        if page_number < len(pdf_document):
            print("Processing Page Number: "+str(page_number))
            page = pdf_document[page_number]
            image_list = page.get_images(full=True)

            if image_list:
                # Extract and process the image
                base_image = image_list[0]
                xref = base_image[0]
                base_image = pdf_document.extract_image(xref)
                image_bytes = base_image["image"]
                image = Image.open(io.BytesIO(image_bytes))
                text = pytesseract.image_to_string(image)

                # Update the current topic if a new chapter is found
                topic_match = topic_pattern.search(text)
                if topic_match:
                    current_topic = topic_match.group(1).strip()

                # Find all questions and dates on the current page
                questions = question_pattern.findall(text)
                dates = date_pattern.findall(text)

                # Check if the number of questions matches the number of dates
                if len(questions) != len(dates):
                    print(f"Mismatch in number of questions and dates on page {page_number}")

                # Append data to the extracted data list
                for question, date in zip(questions, dates):
                    extracted_data.append((question, date, current_topic))
            else:
                print("No image found on page", page_number)
        else:
            print("Page number out of range")

# Close the PDF after processing
pdf_document.close()

# Create a pandas DataFrame
df = pd.DataFrame(extracted_data, columns=['Question', 'Date', 'Topic'])

# Write the DataFrame to an Excel file
excel_output_path = 'output.xlsx'
df.to_excel(excel_output_path, index=False)

print(f"Data has been written to {excel_output_path}")
# Out:
# Processing Page Number: 5
# Mismatch in number of questions and dates on page 5
# Processing Page Number: 6
# Processing Page Number: 7
# Mismatch in number of questions and dates on page 7
# Processing Page Number: 8
# Processing Page Number: 9
# Mismatch in number of questions and dates on page 9
# Processing Page Number: 10
# Mismatch in number of questions and dates on page 10
# Processing Page Number: 11
# Processing Page Number: 12
# Processing Page Number: 13
# Processing Page Number: 14
# Mismatch in number of questions and dates on page 14
# Processing Page Number: 15
# Processing Page Number: 16
# Mismatch in number of questions and dates on page 16
# Processing Page Number: 17
# Mismatch in number of questions and dates on page 17
# Processing Page Number: 18
# Mismatch in number of questions and dates on page 18
# Processing Page Number: 19
# Mismatch in number of questions and dates on page 19
# Processing Page Number: 20
# Mismatch in number of questions and dates on page 20
# Processing Page Number: 21
# Mismatch in number of questions and dates on page 21
# Processing Page Number: 22
# Mismatch in number of questions and dates on page 22
# Processing Page Number: 23
# Processing Page Number: 24
# Processing Page Number: 25
# Mismatch in number of questions and dates on page 25
# Processing Page Number: 26
# Processing Page Number: 27
# Mismatch in number of questions and dates on page 27
# Processing Page Number: 28
# Mismatch in number of questions and dates on page 28
# Processing Page Number: 29
# Mismatch in number of questions and dates on page 29
# Processing Page Number: 30
# Mismatch in number of questions and dates on page 30
# Processing Page Number: 31
# Processing Page Number: 32
# Mismatch in number of questions and dates on page 32
# Processing Page Number: 33
# Mismatch in number of questions and dates on page 33
# Processing Page Number: 34
# Mismatch in number of questions and dates on page 34
# Processing Page Number: 35
# Mismatch in number of questions and dates on page 35
# Processing Page Number: 36
# Mismatch in number of questions and dates on page 36
# Processing Page Number: 37
# Processing Page Number: 38
# Mismatch in number of questions and dates on page 38
# Processing Page Number: 39
# Mismatch in number of questions and dates on page 39
# Processing Page Number: 40
# Mismatch in number of questions and dates on page 40
# Processing Page Number: 41
# Mismatch in number of questions and dates on page 41
# Processing Page Number: 42
# Mismatch in number of questions and dates on page 42
# Processing Page Number: 43
# Processing Page Number: 44
# Mismatch in number of questions and dates on page 44
# Processing Page Number: 45
# Processing Page Number: 46
# Mismatch in number of questions and dates on page 46
# Processing Page Number: 47
# Mismatch in number of questions and dates on page 47
# Processing Page Number: 48
# Mismatch in number of questions and dates on page 48
# Processing Page Number: 49
# Mismatch in number of questions and dates on page 49
# Processing Page Number: 50
# Mismatch in number of questions and dates on page 50
# Processing Page Number: 51
# Processing Page Number: 52
# Mismatch in number of questions and dates on page 52
# Processing Page Number: 53
# Processing Page Number: 54
# Mismatch in number of questions and dates on page 54
# Processing Page Number: 55
# Mismatch in number of questions and dates on page 55
# Processing Page Number: 56
# Mismatch in number of questions and dates on page 56
# Processing Page Number: 57
# Mismatch in number of questions and dates on page 57
# Processing Page Number: 58
# Mismatch in number of questions and dates on page 58
# Processing Page Number: 59
# Mismatch in number of questions and dates on page 59
# Processing Page Number: 60
# Mismatch in number of questions and dates on page 60
# Processing Page Number: 61
# Mismatch in number of questions and dates on page 61
# Processing Page Number: 62
# Mismatch in number of questions and dates on page 62
# Processing Page Number: 63
# Mismatch in number of questions and dates on page 63
# Processing Page Number: 64
# Mismatch in number of questions and dates on page 64
# Processing Page Number: 65
# Mismatch in number of questions and dates on page 65
# Processing Page Number: 66
# Mismatch in number of questions and dates on page 66
# Processing Page Number: 67
# Mismatch in number of questions and dates on page 67
# Processing Page Number: 68
# Mismatch in number of questions and dates on page 68
# Processing Page Number: 69
# Processing Page Number: 70
# Processing Page Number: 71
# Mismatch in number of questions and dates on page 71
# Processing Page Number: 72
# Mismatch in number of questions and dates on page 72
# Processing Page Number: 73
# Mismatch in number of questions and dates on page 73
# Processing Page Number: 74
# Mismatch in number of questions and dates on page 74
# Processing Page Number: 75
# Mismatch in number of questions and dates on page 75
# Processing Page Number: 76
# Mismatch in number of questions and dates on page 76
# Processing Page Number: 77
# Mismatch in number of questions and dates on page 77
# Processing Page Number: 78
# Processing Page Number: 79
# Mismatch in number of questions and dates on page 79
# Processing Page Number: 80
# Mismatch in number of questions and dates on page 80
# Processing Page Number: 81
# Mismatch in number of questions and dates on page 81
# Processing Page Number: 82
# Mismatch in number of questions and dates on page 82
# Processing Page Number: 83
# Mismatch in number of questions and dates on page 83
# Processing Page Number: 84
# Mismatch in number of questions and dates on page 84
# Processing Page Number: 85
# Mismatch in number of questions and dates on page 85
# Processing Page Number: 86
# Mismatch in number of questions and dates on page 86
# Processing Page Number: 87
# Mismatch in number of questions and dates on page 87
# Processing Page Number: 88
# Mismatch in number of questions and dates on page 88
# Processing Page Number: 89
# Mismatch in number of questions and dates on page 89
# Processing Page Number: 90
# Mismatch in number of questions and dates on page 90
# Processing Page Number: 91
# Mismatch in number of questions and dates on page 91
# Processing Page Number: 92
# Mismatch in number of questions and dates on page 92
# Processing Page Number: 93
# Mismatch in number of questions and dates on page 93
# Processing Page Number: 94
# Processing Page Number: 95
# Mismatch in number of questions and dates on page 95
# Processing Page Number: 96
# Mismatch in number of questions and dates on page 96
# Processing Page Number: 97
# Mismatch in number of questions and dates on page 97
# Processing Page Number: 98
# Mismatch in number of questions and dates on page 98
# Processing Page Number: 99
# Mismatch in number of questions and dates on page 99
# Processing Page Number: 100
# Processing Page Number: 101
# Mismatch in number of questions and dates on page 101
# Processing Page Number: 102
# Processing Page Number: 103
# Mismatch in number of questions and dates on page 103
# Processing Page Number: 104
# Mismatch in number of questions and dates on page 104
# Processing Page Number: 105
# Mismatch in number of questions and dates on page 105
# Processing Page Number: 106
# Processing Page Number: 107
# Mismatch in number of questions and dates on page 107
# Processing Page Number: 108
# Mismatch in number of questions and dates on page 108
# Processing Page Number: 109
# Mismatch in number of questions and dates on page 109
# Processing Page Number: 110
# Mismatch in number of questions and dates on page 110
# Processing Page Number: 111
# Processing Page Number: 112
# Mismatch in number of questions and dates on page 112
# Processing Page Number: 113
# Mismatch in number of questions and dates on page 113
# Processing Page Number: 114
# Mismatch in number of questions and dates on page 114
# Processing Page Number: 115
# Mismatch in number of questions and dates on page 115
# Processing Page Number: 116
# Mismatch in number of questions and dates on page 116
# Processing Page Number: 117
# Mismatch in number of questions and dates on page 117
# Processing Page Number: 118
# Mismatch in number of questions and dates on page 118
# Processing Page Number: 119
# Mismatch in number of questions and dates on page 119
# Processing Page Number: 120
# Mismatch in number of questions and dates on page 120
# Processing Page Number: 121
# Mismatch in number of questions and dates on page 121
# Processing Page Number: 122
# Mismatch in number of questions and dates on page 122
# Processing Page Number: 123
# Mismatch in number of questions and dates on page 123
# Processing Page Number: 124
# Mismatch in number of questions and dates on page 124
# Processing Page Number: 125
# Mismatch in number of questions and dates on page 125
# Processing Page Number: 126
# Mismatch in number of questions and dates on page 126
# Processing Page Number: 127
# Mismatch in number of questions and dates on page 127
# Processing Page Number: 128
# Processing Page Number: 129
# Mismatch in number of questions and dates on page 129
# Processing Page Number: 130
# Mismatch in number of questions and dates on page 130
# Processing Page Number: 131
# Mismatch in number of questions and dates on page 131
# Processing Page Number: 132
# Mismatch in number of questions and dates on page 132
# Processing Page Number: 133
# Mismatch in number of questions and dates on page 133
# Processing Page Number: 134
# Mismatch in number of questions and dates on page 134
# Processing Page Number: 135
# Mismatch in number of questions and dates on page 135
# Processing Page Number: 136
# Mismatch in number of questions and dates on page 136
# Processing Page Number: 137
# Mismatch in number of questions and dates on page 137
# Processing Page Number: 138
# Mismatch in number of questions and dates on page 138
# Processing Page Number: 139
# Mismatch in number of questions and dates on page 139
# Processing Page Number: 140
# Mismatch in number of questions and dates on page 140
# Processing Page Number: 141
# Mismatch in number of questions and dates on page 141
# Processing Page Number: 142
# Mismatch in number of questions and dates on page 142
# Processing Page Number: 143
# Mismatch in number of questions and dates on page 143
# Processing Page Number: 144
# Mismatch in number of questions and dates on page 144
# Processing Page Number: 145
# Mismatch in number of questions and dates on page 145
# Processing Page Number: 146
# Mismatch in number of questions and dates on page 146
# Processing Page Number: 147
# Mismatch in number of questions and dates on page 147
# Processing Page Number: 148
# Mismatch in number of questions and dates on page 148
# Processing Page Number: 149
# Mismatch in number of questions and dates on page 149
# Processing Page Number: 150
# Mismatch in number of questions and dates on page 150
# Processing Page Number: 151
# Mismatch in number of questions and dates on page 151
# Processing Page Number: 152
# Mismatch in number of questions and dates on page 152
# Processing Page Number: 153
# Mismatch in number of questions and dates on page 153
# Processing Page Number: 154
# Mismatch in number of questions and dates on page 154
# Processing Page Number: 155
# Mismatch in number of questions and dates on page 155
# Processing Page Number: 156
# Mismatch in number of questions and dates on page 156
# Processing Page Number: 157
# Mismatch in number of questions and dates on page 157
# Processing Page Number: 158
# Mismatch in number of questions and dates on page 158
# Processing Page Number: 159
# Mismatch in number of questions and dates on page 159
# Processing Page Number: 160
# Mismatch in number of questions and dates on page 160
# Processing Page Number: 161
# Mismatch in number of questions and dates on page 161
# Processing Page Number: 162
# Mismatch in number of questions and dates on page 162
# Processing Page Number: 163
# Mismatch in number of questions and dates on page 163
# Processing Page Number: 164
# Mismatch in number of questions and dates on page 164
# Processing Page Number: 165

# %% [markdown]
# ## Calculate Weightage

# %%
import pandas as pd

# Load the Excel file into a pandas DataFrame
excel_path = 'output.xlsx'  # Replace with the path to your Excel file
df = pd.read_excel(excel_path)

# Convert the 'Date' column to datetime objects and extract the year
df['Year'] = pd.to_datetime(df['Date'], errors='coerce').dt.year

# Remove rows with invalid dates
df = df.dropna(subset=['Year'])
df['Year'] = df['Year'].astype(int)

# Calculate the total number of questions per year
total_questions_per_year = df['Year'].value_counts()

# Calculate the number of questions per topic per year
topic_weightage_per_year = df.groupby(['Topic', 'Year']).size()

# Function to get the weightage of a topic in a specific year
def get_topic_weightage(topic, year):
    if year in total_questions_per_year and (topic, year) in topic_weightage_per_year:
        weightage = topic_weightage_per_year[topic, year] / total_questions_per_year[year]
        return weightage
    else:
        return 0  # Return zero weightage if the topic or year is not present

# Example usage
specified_topic = 'TIME AND WORK'  # Replace with your topic
specified_year = 2022  # Replace with your year
weightage = get_topic_weightage(specified_topic, specified_year)

print(f"The weightage of topic '{specified_topic}' in the year {specified_year} is: {weightage:.2%}")

# %% [markdown]
# ## Plot Weightage VS Topic

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Excel file into a pandas DataFrame
excel_path = 'output.xlsx'  # Replace with the path to your Excel file
df = pd.read_excel(excel_path)

# Convert the 'Date' column to datetime objects and extract the year
df['Year'] = pd.to_datetime(df['Date'], errors='coerce').dt.year

# Remove rows with invalid dates
df = df.dropna(subset=['Year'])
df['Year'] = df['Year'].astype(int)

# Calculate the total number of questions per year
total_questions_per_year = df['Year'].value_counts()

# Calculate the number of questions per topic per year
topic_weightage_per_year = df.groupby(['Topic', 'Year']).size().unstack(fill_value=0)

# Normalize the data by dividing by the total questions per year to get weightage
topic_weightage = topic_weightage_per_year.divide(total_questions_per_year, axis='columns')

# Select a specific year to plot the weightage
specified_year = 2022  # Replace with your year
weightage_data = topic_weightage[specified_year].dropna()

# Plot the data
plt.figure(figsize=(10, 8))
weightage_data.plot(kind='bar')
plt.title(f'Topic Weightage in {specified_year}')
plt.xlabel('Topic')
plt.ylabel('Weightage')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()  # Adjust the layout to fit all labels

# Show the plot
plt.show()
